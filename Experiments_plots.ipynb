# %%
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import numpy as np

writer = SummaryWriter()

# %% [markdown]
# # Experiment 1

# %%
event_acc = EventAccumulator('/home/gm3044/Practical_Deep_Learning_Project/NormalBase')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/Train', 'LR', 'Loss/Eval'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
_, _, Loss = zip(*event_acc.Scalars('Loss/Train'))
_, _, val_Loss = zip(*event_acc.Scalars('Loss/Eval'))
_, Epochs, _ = zip(*event_acc.Scalars('LR'))

Train_loss = list(Loss)
Val_loss = list(val_Loss)
Steps = list(Epochs)

# %%
Loss = []
Val_Loss = []
for i in range(len(Train_loss)-100):
    Loss.append(Train_loss[i+100])
for i in range(len(Val_loss)-100):
    Val_Loss.append(Val_loss[i+100])

# %%
Loss = []
for i in range(0, len(Train_loss),100):
    Loss.append(Train_loss[i])
Val_Loss = []
for i in range(0, len(Val_loss),79):
    Val_Loss.append(Val_loss[i])

# %%
epochs = range(0, 100)

plt.figure(figsize=(10,5))
plt.title("Experiment 1: Training and Validation Loss")
plt.plot(epochs, Val_Loss,label="Validation Loss")
plt.plot(epochs, Loss,label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Experiment 1: Adversarial Training_PGD

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
event_acc = EventAccumulator('/home/gm3044/Practical_Deep_Learning_Project/Adv_Base_PGD')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/Train', 'LR', 'Loss/Eval'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
_, _, Loss = zip(*event_acc.Scalars('Loss/Train'))
_, _, val_Loss = zip(*event_acc.Scalars('Loss/Eval'))
_, Epochs, _ = zip(*event_acc.Scalars('LR'))

Train_loss = list(Loss)
Val_loss = list(val_Loss)
Steps = list(Epochs)

Loss = []
for i in range(0, len(Train_loss),100):
    Loss.append(Train_loss[i])
Val_Loss = []
for i in range(0, len(Val_loss),79):
    Val_Loss.append(Val_loss[i])
len(Loss),len(Val_Loss)
# Out:
# (100, 100)

# %%
epochs = range(0, 100)

plt.figure(figsize=(10,5))
plt.title("Experiment 1 Adversarial Training_PGD: Training and Validation Loss")
plt.plot(epochs, Val_Loss,label="Validation Loss")
plt.plot(epochs, Loss,label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Experiment 1: Adversarial Training_NIFGSM

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
event_acc = EventAccumulator('/home/gm3044/Practical_Deep_Learning_Project/Adv_Base_nifgsm')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/Train', 'LR', 'Loss/Eval'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
_, _, Loss = zip(*event_acc.Scalars('Loss/Train'))
_, _, val_Loss = zip(*event_acc.Scalars('Loss/Eval'))
_, Epochs, _ = zip(*event_acc.Scalars('LR'))

Train_loss = list(Loss)
Val_loss = list(val_Loss)
Steps = list(Epochs)

Loss = []
for i in range(0, len(Train_loss),100):
    Loss.append(Train_loss[i])
Val_Loss = []
for i in range(0, len(Val_loss),83):
    Val_Loss.append(Val_loss[i])
len(Loss),len(Val_Loss)
# Out:
# (100, 101)

# %%
epochs = range(0, 100)

plt.figure(figsize=(10,5))
plt.title("Experiment 1 Adversarial Training_NIFGSM: Training and Validation Loss")
plt.plot(epochs, Val_Loss[:100],label="Validation Loss")
plt.plot(epochs, Loss,label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Experiment 1: Adversarial Training_VMIFGSM

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
event_acc = EventAccumulator('/home/gm3044/Practical_Deep_Learning_Project/Adv_Base_vmifgsm')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/Train', 'LR', 'Loss/Eval'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
_, _, Loss = zip(*event_acc.Scalars('Loss/Train'))
_, _, val_Loss = zip(*event_acc.Scalars('Loss/Eval'))
_, Epochs, _ = zip(*event_acc.Scalars('LR'))

Train_loss = list(Loss)
Val_loss = list(val_Loss)
Steps = list(Epochs)


Loss = []
for i in range(0, len(Train_loss),100):
    Loss.append(Train_loss[i])
Val_Loss = []
for i in range(0, len(Val_loss),79):
    Val_Loss.append(Val_loss[i])
len(Loss),len(Val_Loss)
# Out:
# (100, 100)

# %%
epochs = range(0, 100)

plt.figure(figsize=(10,5))
plt.title("Experiment 1 Adversarial Training_VMIFGSM: Training and Validation Loss")
plt.plot(epochs, Val_Loss[:100],label="Validation Loss")
plt.plot(epochs, Loss,label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Experiment 2_Part1: Transfor Learning FC Layer

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
event_acc = EventAccumulator('/home/gm3044/Practical_Deep_Learning_Project/Standard_Resnet_Transfer')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/Train', 'LR', 'Loss/Eval'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
_, _, Loss = zip(*event_acc.Scalars('Loss/Train'))
_, _, val_Loss = zip(*event_acc.Scalars('Loss/Eval'))
_, Epochs, _ = zip(*event_acc.Scalars('LR'))

Train_loss = list(Loss)
Val_loss = list(val_Loss)
Steps = list(Epochs)


Loss = []
for i in range(0, len(Train_loss),100):
    Loss.append(Train_loss[i])
Val_Loss = []
for i in range(0, len(Val_loss),79):
    Val_Loss.append(Val_loss[i])
len(Loss),len(Val_Loss)
# Out:
# (100, 100)

# %%
epochs = range(0, 100)

plt.figure(figsize=(10,5))
plt.title("Experiment 2 Transfer Learning FC Layer: Training and Validation Loss")
plt.plot(epochs, Val_Loss[:100],label="Validation Loss")
plt.plot(epochs, Loss,label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Experiment 2 Part 1:  Adversarial Training PGD

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
event_acc = EventAccumulator('/home/gm3044/Practical_Deep_Learning_Project/Adv_trans_resnet_PGD')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/Train', 'LR', 'Loss/Eval'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
_, _, Loss = zip(*event_acc.Scalars('Loss/Train'))
_, _, val_Loss = zip(*event_acc.Scalars('Loss/Eval'))
_, Epochs, _ = zip(*event_acc.Scalars('LR'))

Train_loss = list(Loss)
Val_loss = list(val_Loss)
Steps = list(Epochs)

Loss = []
for i in range(0, len(Train_loss),100):
    Loss.append(Train_loss[i])
Val_Loss = []
for i in range(0, len(Val_loss),79):
    Val_Loss.append(Val_loss[i])
len(Loss),len(Val_Loss)
# Out:
# (100, 100)

# %%
epochs = range(0, 100)

plt.figure(figsize=(10,5))
plt.title("Experiment 2 Transfer Learning FC Layer: Training and Validation Loss")
plt.plot(epochs, Val_Loss[:100],label="Validation Loss")
plt.plot(epochs, Loss,label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Experiment 2 Part 2: Transfer Learning Model From Sratch

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
event_acc = EventAccumulator('/home/gm3044/Practical_Deep_Learning_Project/Standard_Resnet_Scratch')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/Train', 'LR', 'Loss/Eval'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
_, _, Loss = zip(*event_acc.Scalars('Loss/Train'))
_, _, val_Loss = zip(*event_acc.Scalars('Loss/Eval'))
_, Epochs, _ = zip(*event_acc.Scalars('LR'))

Train_loss = list(Loss)
Val_loss = list(val_Loss)
Steps = list(Epochs)

Loss = []
for i in range(0, len(Train_loss),100):
    Loss.append(Train_loss[i])
Val_Loss = []
for i in range(0, len(Val_loss),79):
    Val_Loss.append(Val_loss[i])
len(Loss),len(Val_Loss)
# Out:
# (100, 100)

# %%
epochs = range(0, 100)

plt.figure(figsize=(10,5))
plt.title("Experiment 2 Transfer Learning from Sratch: Training and Validation Loss")
plt.plot(epochs, Val_Loss[:100],label="Validation Loss")
plt.plot(epochs, Loss,label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Experiment 2 Part 2: Transfer Learning Model From Sratch w PGD

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
event_acc = EventAccumulator('/home/gm3044/Practical_Deep_Learning_Project/Adv_trans_resnet_scratch_PGD')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/Train', 'LR', 'Loss/Eval'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
_, _, Loss = zip(*event_acc.Scalars('Loss/Train'))
_, _, val_Loss = zip(*event_acc.Scalars('Loss/Eval'))
_, Epochs, _ = zip(*event_acc.Scalars('LR'))

Train_loss = list(Loss)
Val_loss = list(val_Loss)
Steps = list(Epochs)


Loss = []
for i in range(0, len(Train_loss),100):
    Loss.append(Train_loss[i])
Val_Loss = []
for i in range(0, len(Val_loss),86):
    Val_Loss.append(Val_loss[i])
len(Loss),len(Val_Loss)
# Out:
# (100, 102)

# %%
epochs = range(0, 100)

plt.figure(figsize=(10,5))
plt.title("Experiment 2 Transfer Learning from Sratch with Adversarial Training PGD: Training and Validation Loss")
plt.plot(epochs, Val_Loss[:100],label="Validation Loss")
plt.plot(epochs, Loss,label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Experiment 5: Transfer Learning Model From Sratch with 10 Epochs

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
event_acc = EventAccumulator('/home/gm3044/Practical_Deep_Learning_Project/Adv_trans_resnet_scratch_PGD_10')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/Train', 'LR', 'Loss/Eval'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
_, _, Loss = zip(*event_acc.Scalars('Loss/Train'))
_, _, val_Loss = zip(*event_acc.Scalars('Loss/Eval'))
_, Epochs, _ = zip(*event_acc.Scalars('LR'))

Train_loss = list(Loss)
Val_loss = list(val_Loss)
Steps = list(Epochs)

Loss = []
for i in range(0, len(Train_loss),390):
    Loss.append(Train_loss[i])
Val_Loss = []
for i in range(0, len(Val_loss),70):
    Val_Loss.append(Val_loss[i])
len(Loss),len(Val_Loss)
# Out:
# (11, 12)

# %%
epochs = range(0, 100)

plt.figure(figsize=(10,5))
plt.title("Experiment 5 Transfer Learning from Sratch with 10 Epochs: Training and Validation Loss")
plt.plot(epochs[:10], Val_Loss[:10],label="Validation Loss")
plt.plot(epochs[:10], Loss[:10],label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Experiment 4 using CIFAR 100

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
event_acc = EventAccumulator('/home/gm3044/Practical_Deep_Learning_Project/Standard_Resnet_Scratch_100')
event_acc.Reload()
# Show all tags in the log file
print(event_acc.Tags())
# Out:
# {'images': [], 'audio': [], 'histograms': [], 'scalars': ['Loss/Train', 'LR', 'Loss/Eval'], 'distributions': [], 'tensors': [], 'graph': False, 'meta_graph': False, 'run_metadata': []}

# %%
_, _, Loss = zip(*event_acc.Scalars('Loss/Train'))
_, _, val_Loss = zip(*event_acc.Scalars('Loss/Eval'))
_, Epochs, _ = zip(*event_acc.Scalars('LR'))

Train_loss = list(Loss)
Val_loss = list(val_Loss)
Steps = list(Epochs)

Loss = []
for i in range(0, len(Train_loss),100):
    Loss.append(Train_loss[i])
Val_Loss = []
for i in range(0, len(Val_loss),79):
    Val_Loss.append(Val_loss[i])
len(Loss),len(Val_Loss)
# Out:
# (100, 100)

# %%
epochs = range(0, 100)

plt.figure(figsize=(10,5))
plt.title("Experiment 4 with CIFAR100: Training and Validation Loss")
plt.plot(epochs, Val_Loss[:100],label="Validation Loss")
plt.plot(epochs, Loss,label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()
